# %%
# !pip install folium
# Out:
# Collecting folium
#   Downloading folium-0.17.0-py2.py3-none-any.whl.metadata (3.8 kB)
# Collecting branca>=0.6.0 (from folium)
#   Downloading branca-0.8.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: jinja2>=2.9 in c:\users\hamza\anaconda3\lib\site-packages (from folium) (3.1.3)
# Requirement already satisfied: numpy in c:\users\hamza\anaconda3\lib\site-packages (from folium) (1.26.4)
# Requirement already satisfied: requests in c:\users\hamza\anaconda3\lib\site-packages (from folium) (2.31.0)
# Requirement already satisfied: xyzservices in c:\users\hamza\anaconda3\lib\site-packages (from folium) (2022.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\hamza\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hamza\anaconda3\lib\site-packages (from requests->folium) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hamza\anaconda3\lib\site-packages (from requests->folium) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hamza\anaconda3\lib\site-packages (from requests->folium) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hamza\anaconda3\lib\site-packages (from requests->folium) (2024.2.2)
# Downloading folium-0.17.0-py2.py3-none-any.whl (108 kB)
#    ---------------------------------------- 0.0/108.4 kB ? eta -:--:--
#    ---------------------------------------- 0.0/108.4 kB ? eta -:--:--
#    ----------- ---------------------------- 30.7/108.4 kB 1.4 MB/s eta 0:00:01
#    -------------- ------------------------ 41.0/108.4 kB 991.0 kB/s eta 0:00:01
#    -------------- ------------------------ 41.0/108.4 kB 991.0 kB/s eta 0:00:01
#    -------------------------------------- 108.4/108.4 kB 701.2 kB/s eta 0:00:00
# Downloading branca-0.8.0-py3-none-any.whl (25 kB)
# Installing collected packages: branca, folium
# Successfully installed branca-0.8.0 folium-0.17.0

# %%
# Importer les packages 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
from ipywidgets import interact,widgets
import folium

# %%
# Importer les données
deces_df = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv')
confirme_df = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv')
retabli_df = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv')
etat_df = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/web-data/data/cases_country.csv')

# %%
print(deces_df.shape)
print(confirme_df.shape)
print(retabli_df.shape)
print(etat_df.shape)
# Out:
# (289, 1147)
# (289, 1147)
# (274, 1147)
# (201, 16)

# %%
etat_df.head(10)
# Out:
#         Country_Region          Last_Update       Lat       Long_  Confirmed  \
# 0          Afghanistan  2023-03-10 13:21:02  33.93911   67.709953     209484
# 1              Albania  2023-03-10 13:21:02  41.15330   20.168300     334457
# 2              Algeria  2023-03-10 13:21:02  28.03390    1.659600     271496
# 3              Andorra  2023-03-10 13:21:02  42.50630    1.521800      47890
# 4               Angola  2023-03-10 13:21:02 -11.20270   17.873900     105288
# 5           Antarctica  2023-03-10 13:21:02 -71.94990   23.347000         11
# 6  Antigua and Barbuda  2023-03-10 13:21:02  17.06080  -61.796400       9106
# 7            Argentina  2023-03-10 13:21:02 -38.41610  -63.616700   10044957
# 8              Armenia  2023-03-10 13:21:02  40.06910   45.038200     447308
# 9            Australia  2023-03-10 13:21:02 -25.00000  133.000000   11401996
#
#    Deaths  Recovered  Active  Incident_Rate  People_Tested  \
# 0    7896        NaN     NaN     538.127222            NaN
# 1    3598        NaN     NaN   11621.968170            NaN
# 2    6881        NaN     NaN     619.132366            NaN
# 3     165        NaN     NaN   61981.492267            NaN
# 4    1933        NaN     NaN     320.352770            NaN
# 5       0        NaN     NaN            NaN            NaN
# 6     146        NaN     NaN    9298.668409            NaN
# 7  130472        NaN     NaN   22225.432699            NaN
# 8    8727        NaN     NaN   15095.264161            NaN
# 9   19578        NaN     NaN   44784.486856            NaN
#
#    People_Hospitalized  Mortality_Rate  UID ISO3  Cases_28_Days  \
# 0                  NaN        3.769262    4  AFG            680
# 1                  NaN        1.075774    8  ALB            228
# 2                  NaN        2.534476   12  DZA             90
# 3                  NaN        0.344540   20  AND             30
# 4                  NaN        1.835917   24  AGO            104
# 5                  NaN        0.000000   10  ATA              0
# 6                  NaN        1.603338   28  ATG              0
# 7                  NaN        1.298881   32  ARG           4628
# 8                  NaN        1.951005   51  ARM            976
# 9                  NaN        0.171707   36  AUS          71560
#
#    Deaths_28_Days
# 0             0.0
# 1             2.0
# 2             0.0
# 3             0.0
# 4             2.0
# 5             0.0
# 6             0.0
# 7            35.0
# 8             8.0
# 9           511.0

# %%
country=['China','Germany','Morocco']
etat_df[etat_df['Country_Region'].isin(country)]
# Out:
#     Country_Region          Last_Update        Lat       Long_  Confirmed  \
# 37           China  2023-03-10 13:21:02  30.592800  114.305500    4903524
# 67         Germany  2023-03-10 13:21:02  51.165691   10.451526   38249060
# 123        Morocco  2023-03-10 13:21:02  31.791700   -7.092600    1272490
#
#      Deaths  Recovered  Active  Incident_Rate  People_Tested  \
# 37   101056        NaN     NaN     347.329501            NaN
# 67   168935        NaN     NaN   45997.289088            NaN
# 123   16296        NaN     NaN    3447.495971            NaN
#
#      People_Hospitalized  Mortality_Rate  UID ISO3  Cases_28_Days  \
# 37                   NaN        2.060885  156  CHN              8
# 67                   NaN        0.441671  276  DEU         355168
# 123                  NaN        1.280639  504  MAR            167
#
#      Deaths_28_Days
# 37             58.0
# 67           2275.0
# 123             0.0

# %%
etat_df.columns
# Out:
# Index(['Country_Region', 'Last_Update', 'Lat', 'Long_', 'Confirmed', 'Deaths',
#        'Recovered', 'Active', 'Incident_Rate', 'People_Tested',
#        'People_Hospitalized', 'Mortality_Rate', 'UID', 'ISO3', 'Cases_28_Days',
#        'Deaths_28_Days'],
#       dtype='object')

# %%
# Afficher les statistiques au niveau monde
global_data=etat_df.copy().drop(['Country_Region','Last_Update', 'Lat', 'Long_','Active', 'Incident_Rate', 'People_Tested',
       'People_Hospitalized', 'Mortality_Rate', 'UID', 'ISO3'],axis=1)
global_synthese=pd.DataFrame(global_data.sum()).transpose()
global_synthese
# Out:
#      Confirmed     Deaths  Recovered  Cases_28_Days  Deaths_28_Days
# 0  676609955.0  6881955.0        0.0      4015061.0         27523.0

# %%
# Visualiser les pays les plus touchés
fig=go.FigureWidget(layout=go.Layout())
def highlight_col(x):
  r='background-color:red'
  y='background-color:purple'
  g='background-color:grey'
  df1=pd.DataFrame('',index=x.index,columns=x.columns)
  df1.iloc[:,4]=y
  df1.iloc[:,5]=r
  df1.iloc[:,6]=g

  return df1

def show_cases(n):
  n=int(n)
  return etat_df.sort_values('Confirmed',ascending=False).head(n).style.apply(highlight_col,axis=None)

interact(show_cases,n='10')

ipywLayout=widgets.Layout(border='solid 2px green')
ipywLayout.display='none'
widgets.VBox([fig],layout=ipywLayout)
# Out:
# interactive(children=(Text(value='10', description='n'), Output()), _dom_classes=('widget-interact',))
# VBox(children=(FigureWidget({
#     'data': [], 'layout': {'template': '...'}
# }),), layout=Layout(border='solid …

# %%
etat_class_df= etat_df.sort_values('Confirmed',ascending=False)
etat_class_df.columns
# Out:
# Index(['Country_Region', 'Last_Update', 'Lat', 'Long_', 'Confirmed', 'Deaths',
#        'Recovered', 'Active', 'Incident_Rate', 'People_Tested',
#        'People_Hospitalized', 'Mortality_Rate', 'UID', 'ISO3', 'Cases_28_Days',
#        'Deaths_28_Days'],
#       dtype='object')

# %%
etat_class_df.columns
px.bar(
   etat_class_df.head(10),
   x= 'Country_Region',
   y= 'Confirmed',
  title='Les 10 pays les plus touchés par coronavirus (cas confirmés)',
  color_discrete_sequence=['pink'],
  height=500,
  width=800
)

# %%
etat_class_df.columns
px.bar(
   etat_class_df.head(10),
   x= 'Country_Region',
   y= 'Deaths',
  title='Les 10 pays les plus touchés par coronavirus (cas decès)',
  color_discrete_sequence=['pink'],
  height=500,
  width=800
)

# %%
# Filter out rows with NaN values in 'Lat' or 'Long'
confirme_df_clean = confirme_df.dropna(subset=['Lat', 'Long'])

m = folium.Map(location=[31.7917, -7.0926], zoom_start=6, max_zoom=12, min_zoom=2)

for i in range(0, len(confirme_df_clean)):
    folium.Circle(
        location=[confirme_df_clean.iloc[i]['Lat'], confirme_df_clean.iloc[i]['Long']],
        fill=True,
        radius=(int((np.log(confirme_df_clean.iloc[i, -1] + 1.00001))) + 0.2) * 50000,
        color='red',
        fill_color='indigo',
        tooltip="<div style='margin: 0; background-color: black; color: white;'>" +
                "<h4 style='text-align:center;font-weight: bold'>" + confirme_df_clean.iloc[i]['Country/Region'] + "</h4>" +
                "<hr style='margin:10px;color: white;'>" +
                "<ul style='color: white;;list-style-type:circle;align-item:left;padding-left:20px;padding-right:20px'>" +
                "<li>Confirme: " + str(confirme_df_clean.iloc[i, -1]) + "</li>" +
                "<li>Deces:   " + str(deces_df.iloc[i, -1]) + "</li>" +
                "<li>Taux de mortalite: " + str(np.round(deces_df.iloc[i, -1] / (confirme_df_clean.iloc[i, -1] + 1.00001) * 100, 2)) + "</li>" +
                "</ul></div>",
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a48231d9a7684aeae7e7a8c42db7ddf4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a48231d9a7684aeae7e7a8c42db7ddf4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a48231d9a7684aeae7e7a8c42db7ddf4 = L.map(
#                 &quot;map_a48231d9a7684aeae7e7a8c42db7ddf4&quot;,
#                 {
#                     center: [31.7917, -7.0926],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_30205b0779b57312852be9a656b6ed93 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 12, &quot;minZoom&quot;: 2, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_30205b0779b57312852be9a656b6ed93.addTo(map_a48231d9a7684aeae7e7a8c42db7ddf4);
#
#
#             var circle_58d03026117382f1219c4f0b70040ee1 = L.circle(
#                 [33.93911, 67.709953],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;indigo&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 610000.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a48231d9a7684aeae7e7a8c42db7ddf4);
#
#
#             circle_58d03026117382f1219c4f0b70040ee1.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;div style=&#x27;margin: 0; background-color: black; color: white;&#x27;&gt;&lt;h4 style=&#x27;text-align:center;font-weight: bold&#x27;&gt;Afghanistan&lt;/h4&gt;&lt;hr style=&#x27;margin:10px;color: white;&#x27;&gt;&lt;ul style=&#x27;color: white;;list-style-type:circle;align-item:left;padding-left:20px;padding-right:20px&#x27;&gt;&lt;li&gt;Confirme: 209451&lt;/li&gt;&lt;li&gt;Deces:   7896&lt;/li&gt;&lt;li&gt;Taux de mortalite: 3.77&lt;/li&gt;&lt;/ul&gt;&lt;/div&gt;
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_17a54f8233707bad229d5d6220eac8bf = L.circle(
#                 [41.1533, 20.1683],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;indigo&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 610000.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a48231d9a7684aeae7e7a8c42db7ddf4);
#
#
#             circle_17a54f8233707bad229d5d6220eac8bf.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;div style=&#x27;margin: 0; background-color: black; color: white;&#x27;&gt;&lt;h4 style=&#x27;text-align:center;font-weight: bold&#x27;&gt;Albania&lt;/h4&gt;&lt;hr style=&#x27;margin:10px;color: white;&#x27;&gt;&lt;ul style=&#x27;color: white;;list-style-type:circle;align-item:left;padding-left:20px;padding-right:20px&#x27;&gt;&lt;li&gt;Confirme: 334457&lt;/li&gt;&lt;li&gt;Deces:   3598&lt;/li&gt;&lt;li&gt;Taux de mortalite: 1.08&lt;/li&gt;&lt;/ul&gt;&lt;/div&gt;
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_d9d9bcf717343744278ad34a7b6b77bd = L.circle(
#                 [28.0339, 1.6596],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;indigo&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 610000.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a48231d9a7684aeae7e7a8c42db7ddf4);
#
#
#             circle_d9d9bcf717343744278ad34a7b6b77bd.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;div style=&#x27;margin: 0; background-color: black; color: white;&#x27;&gt;&lt;h4 style=&#x27;text-align:center;font-weight: bold&#x27;&gt;Algeria&lt;/h4&gt;&lt;hr style=&#x27;margin:10px;color: white;&#x27;&gt;&lt;ul style=&#x27;color: white;;list-style-type:circle;align-item:left;padding-left:20px;padding-right:20px&#x27;&gt;&lt;li&gt;Confirme: 271496&lt;/li&gt;&lt;li&gt;Deces:   6881&lt;/li&gt;&lt;li&gt;Taux de mortalite: 2.53&lt;/li&gt;&lt;/ul&gt;&lt;/div&gt;
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_309860bb3f517f981f93bd0db1ae62b7 = L.circle(
#                 [42.5063, 1.5218],
